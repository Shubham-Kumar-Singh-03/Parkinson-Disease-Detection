# %% [markdown]
# Importing The Dependencies

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Analysis

# %%
df = pd.read_csv('Parkinson-Disease.csv')

# %%
df.head()
# Out:
#              Name  Average \nvocal \nfundamental \nfrequency  \
# 0  phon_R01_S01_1                                    119.992
# 1  phon_R01_S01_2                                    122.400
# 2  phon_R01_S01_3                                    116.682
# 3  phon_R01_S01_4                                    116.676
# 4  phon_R01_S01_5                                    116.014
#
#    Maximum vocal fundamental \nfrequency  \
# 0                                157.302
# 1                                148.650
# 2                                131.111
# 3                                137.871
# 4                                141.781
#
#    Manimum vocal fundamental \nfrequency  MDVP:Jitter \nmeasure(%)  \
# 0                                 74.997                   0.00784
# 1                                113.819                   0.00968
# 2                                111.555                   0.01050
# 3                                111.366                   0.00997
# ...

# %%
df.shape
# Out:
# (1495, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1495 entries, 0 to 1494
# Data columns (total 24 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   Name                                                                                 1495 non-null   object
#  1   Average
# vocal
# fundamental
# frequency                                               1495 non-null   float64
#  2   Maximum vocal fundamental
# frequency                                                 1495 non-null   float64
#  3   Manimum vocal fundamental
# frequency                                                 1495 non-null   float64
#  4   MDVP:Jitter
# measure(%)                                                              1495 non-null   float64
#  5   MDVP:Jitter
# ...

# %%
df.isnull().sum()
# Out:
# Name                                                                                        0
# Average \nvocal \nfundamental \nfrequency                                                   0
# Maximum vocal fundamental \nfrequency                                                       0
# Manimum vocal fundamental \nfrequency                                                       0
# MDVP:Jitter \nmeasure(%)                                                                    0
# MDVP:Jitter \nmeasure(Abs)                                                                  0
# MDVP:Relative \nAverage \nPerturbation                                                      0
# MDVP:Period \nPerturbation \nQuotient                                                       0
# Jitter:average \nabsolute \ndifference of \ndifferences \nbetween \njitter cycles.          0
# MDVP:Shimmer                                                                                0
# ...

# %%
df.describe()
# Out:
#        Average \nvocal \nfundamental \nfrequency  \
# count                                1495.000000
# mean                                  157.622480
# std                                    50.052679
# min                                    88.076605
# 25%                                   115.351000
# 50%                                   145.004136
# 75%                                   198.917992
# max                                   260.879426
#
#        Maximum vocal fundamental \nfrequency  \
# count                            1495.000000
# mean                              160.641240
# std                                50.687015
# min                                95.007396
# 25%                               127.191540
# 50%                               147.846851
# 75%                               182.990419
# max                               592.030000
#
#        Manimum vocal fundamental \nfrequency  MDVP:Jitter \nmeasure(%)  \
# ...

# %%
st = df['status'].value_counts()
st
# Out:
# 1    873
# 0    622
# Name: status, dtype: int64

# %%
df.groupby('status').mean()
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_11072\4081209983.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('status').mean()
#         Average \nvocal \nfundamental \nfrequency  \
# status
# 0                                      195.991816
# 1                                      130.284877
#
#         Maximum vocal fundamental \nfrequency  \
# status
# 0                                  181.300946
# 1                                  145.921496
#
#         Manimum vocal fundamental \nfrequency  MDVP:Jitter \nmeasure(%)  \
# status
# 0                                  134.018791                  0.001547
# 1                                  122.584709                  0.004196
#
#         MDVP:Jitter \nmeasure(Abs)  MDVP:Relative \nAverage \nPerturbation  \
# status
# ...

# %%
st_df = pd.DataFrame({'status': st.index, 'values': st.values})
st_df
# Out:
#    status  values
# 0       1     873
# 1       0     622

# %% [markdown]
# Data Pre-Processing

# %% [markdown]
# Separating the Features & Target

# %%
X = df.drop(columns=['Name', 'status'], axis=1)
Y = df['status']

# %%
print(X)
# Out:
#       Average \nvocal \nfundamental \nfrequency  \
# 0                                    119.992000
# 1                                    122.400000
# 2                                    116.682000
# 3                                    116.676000
# 4                                    116.014000
# ...                                         ...
# 1490                                 150.010755
# 1491                                 227.537473
# 1492                                 214.852958
# 1493                                 226.455476
# 1494                                 127.496237
#
#       Maximum vocal fundamental \nfrequency  \
# 0                                157.302000
# 1                                148.650000
# 2                                131.111000
# 3                                137.871000
# 4                                141.781000
# ...                                     ...
# 1490                             179.393889
# ...

# %%
print(Y)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1490    1
# 1491    0
# 1492    0
# 1493    0
# 1494    1
# Name: status, Length: 1495, dtype: int64

# %% [markdown]
# Seperate the record into test and train

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (1495, 22) (1196, 22) (299, 22)

# %% [markdown]
# Data Standardization

# %%
scalar = StandardScaler()

# %%
scalar.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scalar.transform(X_train)

# %%
X_test = scalar.transform(X_test)

# %%
print(X_train)
# Out:
# [[-1.30490187 -0.62572678  0.09200671 ...  1.6912643  -0.73404096
#    0.3184104 ]
#  [-1.08275777 -0.23259959 -0.49237945 ...  0.89150909  1.63134448
#    1.17398753]
#  [ 1.91956168  1.94292291  1.56487188 ... -0.34704762  0.65264149
#   -1.38063244]
#  ...
#  [-0.57183877 -0.22528236  0.50892319 ... -1.50464729  0.73924557
#   -1.21179909]
#  [-0.40426188 -0.66962579 -1.22805127 ...  0.36430488  0.98427165
#    1.86438926]
#  [-0.71049704 -0.28329947 -0.18939206 ...  1.42673218 -0.89876732
#    0.85024719]]

# %% [markdown]
# Model Training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
# model=LogisticRegression()
# model=RandomForestClassifier()
# model=SVC()
# model=DecisionTreeClassifier()
# model=KNeighborsClassifier()

# %%
model=KNeighborsClassifier()
model.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(Y_train, X_train_prediction)

# %%
print("Accuracy Score of Model: ", training_data_accuracy)
# Out:
# Accuracy Score of Model:  0.9147157190635451

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(Y_test, X_test_prediction)

# %%
print("Accuracy Score of Model: ", test_data_accuracy)
# Out:
# Accuracy Score of Model:  0.8294314381270903

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score,recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

# %%
precision_score(Y_test,X_test_prediction)
# Out:
# 0.8342857142857143

# %%
f1_score(Y_test,X_test_prediction)
# Out:
# 0.8513119533527697

# %%
recall_score(Y_test,X_test_prediction)
# Out:
# 0.8690476190476191

# %%
model.fit(X_train, Y_train)
test_survival=model.predict(X_train)
test_survival #Predicted label using training data
# Out:
# array([1, 1, 0, ..., 1, 1, 1], dtype=int64)

# %%
confusion_matrix(Y_train,test_survival)
# Out:
# array([[427,  64],
#        [ 38, 667]], dtype=int64)

# %%
accuracy_score(Y_test,X_test_prediction)
# Out:
# 0.8294314381270903

# %%
input_data = (119.992,157.302,74.997,0.00784,7.00E-05,0.0037,0.00554,0.01109,0.04374,0.426,0.02182,0.0313,0.02971,0.06545,0.02211,21.033,0.414783,0.815285,-4.813031,0.266482,2.301442,0.284654)

#changing input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

#reshaping the numpy array
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

# Standardize the data
std_data = scalar.transform(input_data_reshaped)

prediction = model.predict(std_data)
print(prediction)

if(prediction[0] == 0):
    print("The Person does not have Parkinson Disease")
else:
    print("The Person is Suffering from Parkinson")
# Out:
# [1]
# The Person is Suffering from Parkinson
# c:\Users\singh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
